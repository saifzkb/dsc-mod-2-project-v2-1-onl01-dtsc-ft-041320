# %%
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np
import seaborn as sns
import string
import warnings
warnings.simplefilter("ignore")
from statsmodels.formula.api import ols
from statsmodels.stats.outliers_influence import variance_inflation_factor
import statsmodels.api as sm
import scipy.stats as stats
from sklearn.model_selection import train_test_split, cross_val_score
from sklearn.feature_selection import RFE

# %%
df = pd.read_csv("master_df.csv")

# %%
df.head()
# Out:
#          date     price  bedrooms  bathrooms  sqft_living  sqft_lot  floors  \
# 0  2014-10-13  221900.0         3       1.00         1180      5650     1.0
# 1  2014-12-09  538000.0         3       2.25         2570      7242     2.0
# 2  2015-02-25  180000.0         2       1.00          770     10000     1.0
# 3  2014-12-09  604000.0         4       3.00         1960      5000     1.0
# 4  2015-02-18  510000.0         3       2.00         1680      8080     1.0
#
#    waterfront  view  condition  ...  zipcode      lat     long  sqft_living15  \
# 0           0     0          3  ...    98178  47.5112 -122.257           1340
# 1           0     0          3  ...    98125  47.7210 -122.319           1690
# 2           0     0          3  ...    98028  47.7379 -122.233           2720
# 3           0     0          5  ...    98136  47.5208 -122.393           1360
# 4           0     0          3  ...    98074  47.6168 -122.045           1800
#
# ...

# %%
df_features = df[['floors','age_when_sold','view']]

# %%
df_features['bedrooms+bathrooms'] = df['bedrooms'] + df['bathrooms']

# %%
df_features
# Out:
#        floors  age_when_sold  view  sqft_above  bedrooms+bathrooms
# 0         1.0             59     0      1180.0                4.00
# 1         2.0             63     0      2170.0                5.25
# 2         1.0             82     0       770.0                3.00
# 3         1.0             49     0      1050.0                7.00
# 4         1.0             28     0      1680.0                5.00
# ...       ...            ...   ...         ...                 ...
# 21592     3.0              5     0      1530.0                5.50
# 21593     2.0              1     0      2310.0                6.50
# 21594     2.0              5     0      1020.0                2.75
# 21595     2.0             11     0      1600.0                5.50
# 21596     2.0              6     0      1020.0                2.75
#
# [21597 rows x 5 columns]

# %%
df_features_corr = df_features.corr()
df_features_corr
# Out:
#                       floors  age_when_sold      view  sqft_above  \
# floors              1.000000      -0.489514  0.028414    0.519212
# age_when_sold      -0.489514       1.000000  0.054467   -0.420824
# view                0.028414       0.054467  1.000000    0.168057
# sqft_above          0.519212      -0.420824  0.168057    1.000000
# bedrooms+bathrooms  0.373192      -0.361909  0.145960    0.660023
#
#                     bedrooms+bathrooms
# floors                        0.373192
# age_when_sold                -0.361909
# view                          0.145960
# sqft_above                    0.660023
# bedrooms+bathrooms            1.000000

# %%
abs(df_features_corr) > 0.50
# Out:
#                     floors  age_when_sold   view  sqft_above  \
# floors                True          False  False        True
# age_when_sold        False           True  False       False
# view                 False          False   True       False
# sqft_above            True          False  False        True
# bedrooms+bathrooms   False          False  False        True
#
#                     bedrooms+bathrooms
# floors                           False
# age_when_sold                    False
# view                             False
# sqft_above                        True
# bedrooms+bathrooms                True

# %%
# Begin building the OLS model

# %%
y = df['price']

x = df_features

# %%
X = sm.add_constant(x)

# %%
linreg = sm.OLS(y, X).fit()
print(linreg.summary())
# Out:
#                             OLS Regression Results
# ...
# Dep. Variable:                  price   R-squared:                       0.498
# Model:                            OLS   Adj. R-squared:                  0.498
# Method:                 Least Squares   F-statistic:                     4284.
# Date:                Thu, 04 Jun 2020   Prob (F-statistic):               0.00
# Time:                        02:55:13   Log-Likelihood:            -2.9995e+05
# No. Observations:               21597   AIC:                         5.999e+05
# Df Residuals:                   21591   BIC:                         6.000e+05
# Df Model:                           5
# Covariance Type:            nonrobust
# ...
#                          coef    std err          t      P>|t|      [0.025      0.975]
# --------------------------------------------------------------------------------------
# const              -2.569e+05   1.03e+04    -25.023      0.000   -2.77e+05   -2.37e+05
# ...

# %%
#These are my training and test sets of data.
X_train, X_test, y_train, y_test = train_test_split(df_features,df['price'],test_size=0.2)

# %%
selector = RFE(linreg, n_features_to_select=1)
selector = selector.fit(X_train,y_train)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-98-d04294657883> in <module>
#       1 selector = RFE(linreg, n_features_to_select=1)
# ----> 2 selector = selector.fit(X_train,y_train)
#
# ~\anaconda3\envs\learn-env\lib\site-packages\sklearn\feature_selection\rfe.py in fit(self, X, y)
#     142             The target values.
#     143         """
# --> 144         return self._fit(X, y)
#     145
#     146     def _fit(self, X, y, step_score=None):
#
# ~\anaconda3\envs\learn-env\lib\site-packages\sklearn\feature_selection\rfe.py in _fit(self, X, y, step_score)
#     177
#     178             # Rank the remaining features
# --> 179             estimator = clone(self.estimator)
#     180             if self.verbose > 0:
#     181                 print("Fitting estimator with %d features." % np.sum(support_))
#
# ...
