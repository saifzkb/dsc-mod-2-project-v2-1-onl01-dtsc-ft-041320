# %%
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np
import seaborn as sns
import string

from statsmodels.formula.api import ols
from statsmodels.stats.outliers_influence import variance_inflation_factor
import statsmodels.api as sm
import scipy.stats as stats
from sklearn.linear_model import LinearRegression
from sklearn.model_selection import train_test_split, cross_val_score
from sklearn.preprocessing import StandardScaler
from sklearn.feature_selection import RFE

from sklearn.metrics import r2_score

# %%
#import cleaned dataset
df = pd.read_csv("master_df.csv")

# %%
df.head()
# Out:
#          date     price  bedrooms  bathrooms  sqft_living  sqft_lot  floors  \
# 0  2014-10-13  221900.0         3       1.00         1180      5650     1.0
# 1  2014-12-09  538000.0         3       2.25         2570      7242     2.0
# 2  2015-02-25  180000.0         2       1.00          770     10000     1.0
# 3  2014-12-09  604000.0         4       3.00         1960      5000     1.0
# 4  2015-02-18  510000.0         3       2.00         1680      8080     1.0
#
#    waterfront  view  condition  ...  zipcode      lat     long  sqft_living15  \
# 0           0     0          3  ...    98178  47.5112 -122.257           1340
# 1           0     0          3  ...    98125  47.7210 -122.319           1690
# 2           0     0          3  ...    98028  47.7379 -122.233           2720
# 3           0     0          5  ...    98136  47.5208 -122.393           1360
# 4           0     0          3  ...    98074  47.6168 -122.045           1800
#
# ...

# %%
df.isna().sum()  #verifying that there are no null values
# Out:
# date             0
# price            0
# bedrooms         0
# bathrooms        0
# sqft_living      0
# sqft_lot         0
# floors           0
# waterfront       0
# view             0
# condition        0
# grade            0
# sqft_above       0
# sqft_basement    0
# yr_built         0
# yr_renovated     0
# zipcode          0
# lat              0
# long             0
# sqft_living15    0
# sqft_lot15       0
# basement         0
# year             0
# Renovated        0
# age_when_sold    0
# month            0
# dtype: int64

# %% [markdown]
# ## Resolve multicollinearity

# %%
corr = df.corr()
plt.figure(figsize=(15,15))
sns.heatmap(corr, annot=True, fmt='.1g', cmap=sns.color_palette('Greens'))
plt.show()

# %%
df2 = pd.DataFrame([])
df2 = df.drop(['view', 
                     'condition', 'zipcode', 'date', 'sqft_living15', 'sqft_lot15', 'yr_built'], axis=1)

# %%
df2.columns
# Out:
# Index(['price', 'bedrooms', 'bathrooms', 'sqft_living', 'sqft_lot', 'floors',
#        'waterfront', 'grade', 'sqft_above', 'sqft_basement', 'yr_renovated',
#        'lat', 'long', 'basement', 'year', 'Renovated', 'age_when_sold',
#        'month'],
#       dtype='object')

# %%
df2.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 21597 entries, 0 to 21596
# Data columns (total 18 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   price          21597 non-null  float64
#  1   bedrooms       21597 non-null  int64
#  2   bathrooms      21597 non-null  float64
#  3   sqft_living    21597 non-null  int64
#  4   sqft_lot       21597 non-null  int64
#  5   floors         21597 non-null  float64
#  6   waterfront     21597 non-null  int64
#  7   grade          21597 non-null  int64
#  8   sqft_above     21597 non-null  int64
#  9   sqft_basement  21597 non-null  float64
#  10  yr_renovated   21597 non-null  int64
#  11  lat            21597 non-null  float64
#  12  long           21597 non-null  float64
#  13  basement       21597 non-null  int64
#  14  year           21597 non-null  int64
#  15  Renovated      21597 non-null  int64
#  16  age_when_sold  21597 non-null  int64
# ...

# %%
df3 = df2.drop(['sqft_living', 'sqft_lot', 'sqft_above', 'sqft_basement', 'bathrooms',
                'bedrooms', 'floors', 'grade'], axis=1)

# %%
df3.drop(columns='waterfront')
# Out:
#           price  yr_renovated      lat     long  basement  year  Renovated  \
# 0      221900.0             0  47.5112 -122.257         0  2014          0
# 1      538000.0          1991  47.7210 -122.319         1  2014          1
# 2      180000.0             0  47.7379 -122.233         0  2015          0
# 3      604000.0             0  47.5208 -122.393         1  2014          0
# 4      510000.0             0  47.6168 -122.045         0  2015          0
# ...         ...           ...      ...      ...       ...   ...        ...
# 21592  360000.0             0  47.6993 -122.346         0  2014          0
# 21593  400000.0             0  47.5107 -122.362         0  2015          0
# 21594  402101.0             0  47.5944 -122.299         0  2014          0
# 21595  400000.0             0  47.5345 -122.069         0  2015          0
# 21596  325000.0             0  47.5941 -122.299         0  2014          0
#
#        age_when_sold  month
# 0                 59     10
# ...

# %%
corr1 = df3.corr()
plt.figure(figsize=(15,15))
sns.heatmap(corr1, annot=True, fmt='.1g', cmap=sns.color_palette('Greens'))
plt.show()

# %%
#making OLS model by manually removing features which are causing multicollinearity possibly
target = df3['price']
df4 = df3.drop(['price'], axis=1)

# %%
# Preparing the data
X = df4
#X = sm.add_constant(x)
y = target

# Splitting the dataset into train and validation sets
X_train, X_test, y_train, y_test = train_test_split(X, 
                                                    y, 
                                                    test_size = 0.3, 
                                                    random_state = 10)

# %%
linreg = sm.OLS(y_train, X_train).fit()
linreg.summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                                  OLS Regression Results
# ...
# Dep. Variable:                  price   R-squared (uncentered):                   0.753
# Model:                            OLS   Adj. R-squared (uncentered):              0.752
# Method:                 Least Squares   F-statistic:                              5105.
# Date:                Wed, 03 Jun 2020   Prob (F-statistic):                        0.00
# Time:                        13:53:08   Log-Likelihood:                     -2.1335e+05
# No. Observations:               15117   AIC:                                  4.267e+05
# Df Residuals:                   15108   BIC:                                  4.268e+05
# Df Model:                           9
# Covariance Type:            nonrobust
# ...
#                     coef    std err          t      P>|t|      [0.025      0.975]
# ---------------------------------------------------------------------------------
# ...

# %%
#Implementing Recursive Feature Elimination

# %%
df.drop('date', axis = 1, inplace = True)

# %%
sk_ols = LinearRegression(fit_intercept=False, normalize=False, n_jobs=-1)

# %%
rfe = RFE(sk_ols, n_features_to_select=10, step=1, verbose=2)

# %%
X_all = df.drop(columns=['price', 'lat', 'long', 'month', 'yr_renovated', 'yr_built'])
rfe.fit(X_all, df['price'])
# Out:
# Fitting estimator with 18 features.
# Fitting estimator with 17 features.
# Fitting estimator with 16 features.
# Fitting estimator with 15 features.
# Fitting estimator with 14 features.
# Fitting estimator with 13 features.
# Fitting estimator with 12 features.
# Fitting estimator with 11 features.
# RFE(estimator=LinearRegression(copy_X=True, fit_intercept=False, n_jobs=-1,
#                                normalize=False),
#     n_features_to_select=10, step=1, verbose=2)

# %%
new_cols = X_all.columns[rfe.support_]

# %%
X_new = df[new_cols]
X_new.head()
# Out:
#    bathrooms  floors  waterfront  view  condition  grade  basement  year  \
# 0       1.00     1.0           0     0          3      7         0  2014
# 1       2.25     2.0           0     0          3      7         1  2014
# 2       1.00     1.0           0     0          3      6         0  2015
# 3       3.00     1.0           0     0          5      7         1  2014
# 4       2.00     1.0           0     0          3      8         0  2015
#
#    Renovated  age_when_sold
# 0          0             59
# 1          1             63
# 2          0             82
# 3          0             49
# 4          0             28

# %%
#Function for making OLS model
def make_ols_sklearn(X, y, test_size=0.20, fit_intercept=False, standardize=False):
    X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=test_size)
    if standardize:
        ss = StandardScaler()
        ss.fit(X_train)
        X_train = ss.transform(X_train)
        X_test = ss.transform(X_test)
    ols = LinearRegression(fit_intercept=fit_intercept, normalize=False)
    ols.fit(X_train, y_train)
    train_score = ols.score(X_train, y_train)
    test_score = ols.score(X_test, y_test)
    print(f"train score = {train_score}")
    print(f"test score = {test_score}")
    return ols

# %%
make_ols_sklearn(X_new, df['price'])
# Out:
# train score = 0.6113007130840356
# test score = 0.6087150687110653
# LinearRegression(copy_X=True, fit_intercept=False, n_jobs=None, normalize=False)

# %%
#Cross validation of model
cv_scores = cross_val_score(sk_ols, X_new, df['price'], scoring='r2', cv=10, n_jobs=-1)

# %%
cv_scores
# Out:
# array([0.60679711, 0.60655288, 0.58926546, 0.60638102, 0.58322068,
#        0.61859895, 0.63670846, 0.6241942 , 0.60654577, 0.5951929 ])

# %%
target ='price'

# %%
#train-test split
train, test = train_test_split(df)

# %%
predictors = '+'.join(new_cols)
formula = target + '~' + predictors
model = ols(formula=formula, data=train).fit()
model.summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                             OLS Regression Results
# ...
# Dep. Variable:                  price   R-squared:                       0.608
# Model:                            OLS   Adj. R-squared:                  0.608
# Method:                 Least Squares   F-statistic:                     2508.
# Date:                Wed, 03 Jun 2020   Prob (F-statistic):               0.00
# Time:                        13:31:34   Log-Likelihood:            -2.2336e+05
# No. Observations:               16197   AIC:                         4.467e+05
# Df Residuals:                   16186   BIC:                         4.468e+05
# Df Model:                          10
# Covariance Type:            nonrobust
# ...
#                     coef    std err          t      P>|t|      [0.025      0.975]
# ---------------------------------------------------------------------------------
# ...
