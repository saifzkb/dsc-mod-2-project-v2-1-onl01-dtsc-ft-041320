# %%
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np
import seaborn as sns
import string

from statsmodels.formula.api import ols
from statsmodels.stats.outliers_influence import variance_inflation_factor
import statsmodels.api as sm
import scipy.stats as stats
from sklearn.model_selection import train_test_split, cross_val_score
from sklearn.linear_model import LinearRegression

# %%
df = pd.read_csv('model_df.csv')
df.head()
# Out:
#        price  bedrooms  bathrooms  sqft_living  sqft_lot  floors  view  \
# 0  12.309982         3       1.00     7.073270      5650     1.0     0
# 1  13.195614         3       2.25     7.851661      7242     2.0     0
# 2  12.100712         2       1.00     6.646391     10000     1.0     0
# 3  13.311329         4       3.00     7.580700      5000     1.0     0
# 4  13.142166         3       2.00     7.426549      8080     1.0     0
#
#    condition  grade  sqft_above  ...  distance_from_nearest_hotspot  \
# 0          3      7        1180  ...                       2.662882
# 1          3      7        2170  ...                       2.288785
# 2          3      6         770  ...                       2.311032
# 3          5      7        1050  ...                       2.291486
# 4          3      8        1680  ...                       1.540106
#
#    year_last_renovated  time_since_renovated  total_rooms  condition_grade  \
# 0               1955.0                  60.0         4.00               10
# 1               1991.0                  24.0         5.25               10
# 2               1933.0                  82.0         3.00                9
# 3               1965.0                  50.0         7.00               12
# 4               1987.0                  28.0         5.00               11
#
#    sqft_total   price_o  rooms_cg  condition_grade_sq  time_since_renovated_sq
# 0    7.073270  221900.0     14.00                 100                   3600.0
# 1    8.851661  538000.0     15.25                 100                    576.0
# 2    6.646391  180000.0     12.00                  81                   6724.0
# 3    8.580700  604000.0     19.00                 144                   2500.0
# 4    7.426549  510000.0     16.00                 121                    784.0
#
# [5 rows x 27 columns]

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 19682 entries, 0 to 19681
# Data columns (total 27 columns):
#  #   Column                         Non-Null Count  Dtype
# ---  ------                         --------------  -----
#  0   price                          19682 non-null  float64
#  1   bedrooms                       19682 non-null  int64
#  2   bathrooms                      19682 non-null  float64
#  3   sqft_living                    19682 non-null  float64
#  4   sqft_lot                       19682 non-null  int64
#  5   floors                         19682 non-null  float64
#  6   view                           19682 non-null  int64
#  7   condition                      19682 non-null  int64
#  8   grade                          19682 non-null  int64
#  9   sqft_above                     19682 non-null  int64
#  10  yr_built                       19682 non-null  int64
#  11  yr_renovated                   19682 non-null  int64
#  12  zipcode                        19682 non-null  int64
#  13  basement                       19682 non-null  int64
#  14  Renovated                      19682 non-null  int64
#  15  age_when_sold                  19682 non-null  int64
#  16  distance_from_seattle_km       19682 non-null  float64
#  17  distance_from_nearest_hotspot  19682 non-null  float64
#  18  year_last_renovated            19682 non-null  float64
#  19  time_since_renovated           19682 non-null  float64
#  20  total_rooms                    19682 non-null  float64
#  21  condition_grade                19682 non-null  int64
#  22  sqft_total                     19682 non-null  float64
#  23  price_o                        19682 non-null  float64
#  24  rooms_cg                       19682 non-null  float64
#  25  condition_grade_sq             19682 non-null  int64
#  26  time_since_renovated_sq        19682 non-null  float64
# dtypes: float64(13), int64(14)
# memory usage: 4.1 MB

# %%
plt.figure(figsize=(15, 15))
sns.heatmap(np.abs(df.corr()), center=0, annot =True);
b, t = plt.ylim() # discover the values for bottom and top
b += 0.5 # Add 0.5 to the bottom
t -= 0.5 # Subtract 0.5 from the top
plt.ylim(b, t) # update the ylim(bottom, top) values
plt.show() # ta-da!

# %%
def make_ols_sm(df, cols, add_constant=False, target='price_o'):
    x = df[cols]
    if add_constant:
        x = sm.add_constant(x)
    ols = sm.OLS(df[target], x)
    res = ols.fit()
    print(res.summary())
    return res

# %%
cols = ['time_since_renovated', 'condition_grade_sq', 'Renovated', 'basement', 'view']

res = make_ols_sm(df, cols)
# Out:
#                                  OLS Regression Results
# =======================================================================================
# Dep. Variable:                price_o   R-squared (uncentered):                   0.890
# Model:                            OLS   Adj. R-squared (uncentered):              0.890
# Method:                 Least Squares   F-statistic:                          3.177e+04
# Date:                Thu, 04 Jun 2020   Prob (F-statistic):                        0.00
# Time:                        15:10:49   Log-Likelihood:                     -2.6622e+05
# No. Observations:               19682   AIC:                                  5.325e+05
# Df Residuals:                   19677   BIC:                                  5.325e+05
# Df Model:                           5
# Covariance Type:            nonrobust
# ========================================================================================
#                            coef    std err          t      P>|t|      [0.025      0.975]
# ----------------------------------------------------------------------------------------
# time_since_renovated  -291.3620     42.518     -6.853      0.000    -374.701    -208.023
# condition_grade_sq    3942.9725     18.365    214.701      0.000    3906.976    3978.969
# Renovated              1.26e+05   7488.813     16.831      0.000    1.11e+05    1.41e+05
# basement              4.428e+04   2737.608     16.174      0.000    3.89e+04    4.96e+04
# view                  6.903e+04   2085.072     33.105      0.000    6.49e+04    7.31e+04
# ==============================================================================
# Omnibus:                     3405.862   Durbin-Watson:                   1.965
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):             6989.246
# Skew:                           1.039   Prob(JB):                         0.00
# Kurtosis:                       5.050   Cond. No.                         760.
# ==============================================================================
#
# Warnings:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.

# %%
X = df[cols]
vif = [variance_inflation_factor(X.values, i) for i in range(X.shape[1])]
list(zip(cols, vif))
# Out:
# [('time_since_renovated', 2.8410498876413746),
#  ('condition_grade_sq', 3.1143028769918084),
#  ('Renovated', 1.0503986065798132),
#  ('basement', 1.7405733555157932),
#  ('view', 1.1190630106116475)]

# %%
def plot_residuals(df, res, target='price_o'):
    plt.hist(res.resid)
    plt.show()
    
    plt.scatter(df[target], res.resid)
    plt.hlines(y=0, xmin=0, xmax=df[target].max())
    plt.xlabel(target)
    plt.ylabel('Residuals')
    plt.show()

# %%
plot_residuals(df, res)

# %%
fig = sm.graphics.qqplot(res.resid, dist=stats.norm, line='45', fit=True)
