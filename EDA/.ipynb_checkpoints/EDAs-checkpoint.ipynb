# %%
import pandas as pd
import numpy as np

import matplotlib.pyplot as plt
import matplotlib.ticker as tick

import seaborn as sns
sns.set_style("whitegrid")
# Out:
# C:\Users\saifk\anaconda3\envs\learn-env\lib\site-packages\statsmodels\tools\_testing.py:19: FutureWarning: pandas.util.testing is deprecated. Use the functions in the public API at pandas.testing instead.
#   import pandas.util.testing as tm

# %%
df = pd.read_csv("../Data/master_df.csv")

# %%
df.head()
# Out:
#          date     price  bedrooms  bathrooms  sqft_living  sqft_lot  floors  \
# 0  2014-10-13  221900.0         3       1.00         1180      5650     1.0
# 1  2014-12-09  538000.0         3       2.25         2570      7242     2.0
# 2  2015-02-25  180000.0         2       1.00          770     10000     1.0
# 3  2014-12-09  604000.0         4       3.00         1960      5000     1.0
# 4  2015-02-18  510000.0         3       2.00         1680      8080     1.0
#
#    waterfront  view  condition  ...  zipcode      lat     long  sqft_living15  \
# 0           0     0          3  ...    98178  47.5112 -122.257           1340
# 1           0     0          3  ...    98125  47.7210 -122.319           1690
# 2           0     0          3  ...    98028  47.7379 -122.233           2720
# 3           0     0          5  ...    98136  47.5208 -122.393           1360
# 4           0     0          3  ...    98074  47.6168 -122.045           1800
#
# ...

# %%
df.date.value_counts()
# Out:
# 2014-06-23    142
# 2014-06-26    131
# 2014-06-25    131
# 2014-07-08    127
# 2015-04-27    126
#              ...
# 2015-01-31      1
# 2015-01-10      1
# 2015-01-17      1
# 2015-02-15      1
# 2014-08-30      1
# Name: date, Length: 372, dtype: int64

# %%
#Basic scatterplot between yr_built and price.
plt.figure(figsize=(12,6))
sns.scatterplot(x=df['yr_built'], y=df['price'])
plt.xlabel("Year Built")
plt.ylabel("Price")
plt.show()

# %%
sns.lmplot('yr_built','price',df, line_kws={'color': 'red'}, height=8)
plt.title("price vs yr_built")
plt.show()

# %%
#Plotting Lat vs Long to get a map of homes. The color of the dots represent price.
plt.figure(figsize=(15,8))
sns.scatterplot(df['long'], df['lat'], hue=df['price'], palette='Reds')
plt.legend(loc='lower right')
plt.title("Price by Location")
# Out:
# Text(0.5, 1.0, 'Price by Location')

# %%
#Time since renovated and was it renovated or not vs price
df2 = pd.read_csv("model_df.csv")

# %%
df2.columns
# Out:
# Index(['price', 'bedrooms', 'bathrooms', 'sqft_living', 'sqft_lot', 'floors',
#        'view', 'condition', 'grade', 'sqft_above', 'yr_built', 'yr_renovated',
#        'zipcode', 'basement', 'Renovated', 'age_when_sold',
#        'distance_from_seattle_km', 'distance_from_nearest_hotspot',
#        'year_last_renovated', 'time_since_renovated', 'total_rooms',
#        'condition_grade', 'sqft_total', 'price_o', 'rooms_cg',
#        'condition_grade_sq', 'time_since_renovated_sq'],
#       dtype='object')

# %%
df2.time_since_renovated.head()
# Out:
# 0    60.0
# 1    24.0
# 2    82.0
# 3    50.0
# 4    28.0
# Name: time_since_renovated, dtype: float64

# %%
df2.time_since_renovated.unique()
# Out:
# array([ 60.,  24.,  82.,  50.,  28.,  20.,  52.,  55.,  12.,  73.,  88.,
#         38., 115.,  36.,  21.,  99.,  94.,  46.,  68.,  30.,  74., 100.,
#        106.,  67.,  10.,  86.,  34.,  13., 111.,  19.,  15.,  31.,   1.,
#         93.,  56.,  49.,  62.,  65.,   7.,  47.,  61.,  42.,  90.,  26.,
#         43.,  29.,  59.,  23.,  51.,  63.,  54.,   9.,  27.,  14.,  53.,
#         76.,  48.,  40.,  35., 105.,  32.,   5.,  37., 110.,  44.,  70.,
#         91.,  25.,  89.,  11.,  92.,   8.,  39.,  16., 114.,  66.,  22.,
#         95.,  18.,  72.,  75.,  97.,  87.,  41., 104.,  78., 107.,  84.,
#         58.,  17., 102.,   2.,  85., 108.,  57.,   4.,   3.,  98.,  69.,
#         64.,  83.,  71., 113.,   6.,  45.,  33.,   0.,  81.,  77., 103.,
#         96., 101., 109.,  79., 112.,  80.])

# %%
sns.set(font_scale=1.4)

def reformat_large_tick_values(tick_val, pos):
    """
    Turns large tick values (in the billions, millions and thousands) such as 4500 into 4.5K and also appropriately turns 4000 into 4K (no zero after the decimal).
    """
    if tick_val >= 1000000000:
        val = round(tick_val/1000000000, 1)
        new_tick_format = '{:}B'.format(val)
    elif tick_val >= 1000000:
        val = round(tick_val/1000000, 1)
        new_tick_format = '{:}M'.format(val)
    elif tick_val >= 1000:
        val = round(tick_val/1000, 1)
        new_tick_format = '{:}K'.format(val)
    elif tick_val < 1000:
        new_tick_format = round(tick_val, 1)
    else:
        new_tick_format = tick_val

    # make new_tick_format into a string value
    new_tick_format = str(new_tick_format)
    
    # code below will keep 4.5M as is but change values such as 4.0M to 4M since that zero after the decimal isn't needed
    index_of_decimal = new_tick_format.find(".")
    
    if index_of_decimal != -1:
        value_after_decimal = new_tick_format[index_of_decimal+1]
        if value_after_decimal == "0":
            # remove the 0 after the decimal point since it's not needed
            new_tick_format = new_tick_format[0:index_of_decimal] + new_tick_format[index_of_decimal+2:]
            
    return new_tick_format

# %%
plt.figure(figsize=(13, 8))
sns.lmplot('time_since_renovated','price_o',df2, line_kws={'color': 'red'}, height=8)
ax = plt.gca()
ax.yaxis.set_major_formatter(tick.FuncFormatter(reformat_large_tick_values));
ax.set(xlabel='Time Since Renovated(In Years)', ylabel='Price', title="Price vs Time Since Renovated")
plt.show()

# %%
df2['sqft_o'] = np.exp(df2['sqft_total'])

# %%
plt.figure(figsize=(13, 8))
sns.lmplot('sqft_o','price_o',df2, line_kws={'color': 'red'}, height=8)
ax=plt.gca()
ax.yaxis.set_major_formatter(tick.FuncFormatter(reformat_large_tick_values));
ax.set(xlabel='Square Footage', ylabel='Price', title="Price vs Square Footage")
plt.show()

# %%
plt.figure(figsize=(13,8))
sns.catplot(x = 'basement',y = 'price_o',data=df2, height=8)
ax = plt.gca()
ax.yaxis.set_major_formatter(tick.FuncFormatter(reformat_large_tick_values));
ax.set(xlabel='No Basement                          Has Basement', ylabel='Price', title="Price vs Having a Basement")
plt.show()

# %% [markdown]
# ### Represents the construction quality of improvements. Grades run from grade 1 to 13. Generally defined as:
#
# 1-3 Falls short of minimum building standards. Normally cabin or inferior structure.
#
# 4 Generally older, low quality construction. Does not meet code.
#
# 5 Low construction costs and workmanship. Small, simple design.
#
# 6 Lowest grade currently meeting building code. Low quality materials and simple designs.
#
# 7 Average grade of construction and design. Commonly seen in plats and older sub-divisions.
#
# 8 Just above average in construction and design. Usually better materials in both the exterior and interior finish work.
#
# 9 Better architectural design with extra interior and exterior design and quality.
#
# 10 Homes of this quality generally have high quality features. Finish work is better and more design quality is seen in the floor plans. Generally have a larger square footage.
#
# 11 Custom design and higher quality finish work with added amenities of solid woods, bathroom fixtures and more luxurious options.
#
# 12 Custom design and excellent builders. All materials are of the highest quality and all conveniences are present.
#
# 13 Generally custom designed and built. Mansion level. Large amount of highest quality cabinet work, wood trim, marble, entry ways etc.

# %%
plt.figure(figsize=(13,8))
sns.lmplot(x='grade',y='yr_built',data=df2)
ax = plt.gca()
ax.set(xlabel='Grade', ylabel='Year Built', title="Year Built vs Grade")
plt.show();

# %%
plt.figure(figsize=(13,8))
sns.lmplot(x='view',y='price_o',data=df2)
ax = plt.gca()
ax.yaxis.set_major_formatter(tick.FuncFormatter(reformat_large_tick_values));
ax.set(xlabel='View', ylabel='Price', title="Price vs View")
plt.show()

# %%
plt.figure(figsize=(13,8))
sns.lmplot(x='condition',y='price_o',data=df2)
ax = plt.gca()
ax.yaxis.set_major_formatter(tick.FuncFormatter(reformat_large_tick_values));
plt.show()

# %%
plt.figure(figsize=(12,10))
plt.figure(figsize=(10,6))
sns.scatterplot(x='month',y='price',data=df)
ax = plt.gca()
ax.yaxis.set_major_formatter(tick.FuncFormatter(reformat_large_tick_values));
plt.show()

# %%
plt.figure(figsize=(13, 8))
sns.lmplot(x='distance', y='price_o', data=df2, line_kws={'color': 'red'})
ax=plt.gca()
ax.yaxis.set_major_formatter(tick.FuncFormatter(reformat_large_tick_values));
ax.set(xlabel='Distance from nearest hotspot', ylabel='Price', title="Price vs Distance from nearest hotspot")
plt.show()

# %%
df2['distance'] = np.exp(df2['distance_from_nearest_hotspot'])

# %%
df2.distance.max()
# Out:
# 30.913554565606873

# %%
df.loc[df['bedrooms']==33]
# Out:
#              date     price  bedrooms  bathrooms  sqft_living  sqft_lot  \
# 15856  2014-06-25  640000.0        33       1.75         1620      6000
#
#        floors  waterfront  view  condition  ...  zipcode      lat     long  \
# 15856     1.0           0     0          5  ...    98103  47.6878 -122.331
#
#        sqft_living15  sqft_lot15  basement  year  Renovated  age_when_sold  \
# 15856           1330        4700         1  2014          0             67
#
#        month
# 15856      6
#
# [1 rows x 25 columns]

# %%
df3 = pd.read_csv("kc_house_data.csv")

# %%
df3['date'] = pd.to_datetime(df3['date'])

# %%
df3.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 21597 entries, 0 to 21596
# Data columns (total 21 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   id             21597 non-null  int64
#  1   date           21597 non-null  datetime64[ns]
#  2   price          21597 non-null  float64
#  3   bedrooms       21597 non-null  int64
#  4   bathrooms      21597 non-null  float64
#  5   sqft_living    21597 non-null  int64
#  6   sqft_lot       21597 non-null  int64
#  7   floors         21597 non-null  float64
#  8   waterfront     19221 non-null  float64
#  9   view           21534 non-null  float64
#  10  condition      21597 non-null  int64
#  11  grade          21597 non-null  int64
#  12  sqft_above     21597 non-null  int64
#  13  sqft_basement  21597 non-null  object
#  14  yr_built       21597 non-null  int64
#  15  yr_renovated   17755 non-null  float64
#  16  zipcode        21597 non-null  int64
# ...

# %%
df3.date.max()
# Out:
# Timestamp('2015-05-27 00:00:00')

# %%
df3.date.min()
# Out:
# Timestamp('2014-05-02 00:00:00')

# %%
df3['price'].mean()
# Out:
# 540296.5735055795

# %%
df2.columns
# Out:
# Index(['price', 'bedrooms', 'bathrooms', 'sqft_living', 'sqft_lot', 'floors',
#        'view', 'condition', 'grade', 'sqft_above', 'yr_built', 'yr_renovated',
#        'zipcode', 'basement', 'Renovated', 'age_when_sold',
#        'distance_from_seattle_km', 'distance_from_nearest_hotspot',
#        'year_last_renovated', 'time_since_renovated', 'total_rooms',
#        'condition_grade', 'sqft_total', 'price_o', 'rooms_cg',
#        'condition_grade_sq', 'time_since_renovated_sq', 'sqft_o', 'distance'],
#       dtype='object')

# %%
plt.figure(figsize=(13, 8))
sns.lmplot(x='total_rooms', y='price_o', data=df2, line_kws={'color': 'red'})
ax=plt.gca()
ax.yaxis.set_major_formatter(tick.FuncFormatter(reformat_large_tick_values));
ax.set(xlabel='Total Rooms', ylabel='Price', title="Price vs Total Rooms")
plt.show()

# %%
plt.figure(figsize=(13,8))
sns.lmplot(x='grade',y='price_o',data=df2)
ax = plt.gca()
ax.yaxis.set_major_formatter(tick.FuncFormatter(reformat_large_tick_values));
ax.set(xlabel='Grade', ylabel='Price', title="Price vs Grade")
plt.show();

# %%
sns.violinplot(x=df['basement'],y=df['price'])
plt.title("Price vs Having a Basement")
# Out:
# Text(0.5, 1.0, 'Price vs Having a Basement')

# %%
feature_names = ['bedrooms', 'bathrooms', 'sqft_living', 'sqft_lot', 'floors',
                 'condition', 'grade', 'sqft_above', 'yr_built',
                 'yr_renovated', 'sqft_living15', 'sqft_lot15', 'sqft_basement']

# %%
def feature_plots(feature,target,df):
    """
    Creates a histogram of the desired feature and a scatter plot of the target vs. the feature.
    feature = feature (column) name.
    target = target (column) name.
    df = dataframe containing both the feature and target
    returns nothing
    """
    #Print feature name to screen
    print(feature)
    
    #Histogram using sns distplot
    plt.title("{} histogram".format(feature))
    sns.distplot(df[feature])
    plt.show()
    
    #Scatter Plot using sns lmplot
    sns.lmplot(x=feature, y=target, data=df, line_kws={'color': 'red'})
    plt.title("{} vs {}".format(target, feature))
    plt.show()
    
    pass

# %%
for feature in feature_names:
    feature_plots(feature, 'price', df)
# Out:
# bedrooms
# bathrooms
# sqft_living
# sqft_lot
# floors
# condition
# grade
# sqft_above
# yr_built
# yr_renovated
# sqft_living15
# sqft_lot15
# sqft_basement

# %%
corr = df.corr()
plt.figure(figsize=(15,15))
sns.heatmap(corr, annot=True, fmt='.1g', cmap=sns.color_palette('coolwarm'))
plt.show()
